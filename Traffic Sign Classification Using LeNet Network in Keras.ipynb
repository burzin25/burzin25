# %% [markdown]
# Traffic Sign Classification Using LeNet Network in Keras

# %% [markdown]
# STEP 0: PROBLEM STATEMENT

# %% [markdown]
# In this case study, you have been provided with images of traffic signs and the goal is to train a Deep Network to classify them
#
# The dataset contains 43 different classes of images.
#
# Classes are as listed below:
#
# ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)')
# ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)')
# ( 4, b'Speed limit (70km/h)') ( 5, b'Speed limit (80km/h)')
# ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)')
# ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
# (10, b'No passing for vehicles over 3.5 metric tons')
# (11, b'Right-of-way at the next intersection') (12, b'Priority road')
# (13, b'Yield') (14, b'Stop') (15, b'No vehicles')
# (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
# (18, b'General caution') (19, b'Dangerous curve to the left')
# (20, b'Dangerous curve to the right') (21, b'Double curve')
# (22, b'Bumpy road') (23, b'Slippery road')
# (24, b'Road narrows on the right') (25, b'Road work')
# (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
# (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
# (31, b'Wild animals crossing')
# (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
# (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
# (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
# (40, b'Roundabout mandatory') (41, b'End of no passing')
# (42, b'End of no passing by vehicles over 3.5 metric tons')
# The network used is called Le-Net that was presented by Yann LeCun http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf

# %% [markdown]
# Citation
#
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
#
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }

# %% [markdown]
# STEP 1: IMPORT LIBRARIES AND DATASET

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# import libraries 
import pickle
import seaborn as sns
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import random

# %%
# The pickle module implements binary protocols for serializing and de-serializing a Python object structure.
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
y_validation.shape
# Out:
# (4410,)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
y_test.shape
# Out:
# (12630,)

# %% [markdown]
# STEP 2: IMAGE EXPLORATION

# %%
i = 30205
plt.imshow(X_train[i])
y_train[i]
# Out:
# 15

# %%
i = 3020
plt.imshow(X_validation[i])
y_validation[i]
# Out:
# 7

# %%
i = 2000
plt.imshow(X_test[i])
y_test[i]
# Out:
# 34

# %% [markdown]
# STEP 3: DATA PEPARATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray  = np.sum(X_test/3, axis=3, keepdims=True)
X_validation_gray  = np.sum(X_validation/3, axis=3, keepdims=True)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
i = 610
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])

# %%
i = 610
plt.imshow(X_test_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_test[i])

# %% [markdown]
# # STEP 4: MODEL TRAINING

# %% [markdown]
# The model consists of the following layers:
#
# - STEP 1: THE FIRST CONVOLUTIONAL LAYER #1
#     - Input = 32x32x1
#     - Output = 28x28x6
#     - Output = (Input-filter+1)/Stride* => (32-5+1)/1=28
#     - Used a 5x5 Filter with input depth of 3 and output depth of 6
#     - Apply a RELU Activation function to the output
#     - pooling for input, Input = 28x28x6 and Output = 14x14x6
#
#
#     * Stride is the amount by which the kernel is shifted when the kernel is passed over the image.
#
# - STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#     - Input = 14x14x6
#     - Output = 10x10x16
#     - Layer 2: Convolutional layer with Output = 10x10x16
#     - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#     - Apply a RELU Activation function to the output
#     - Pooling with Input = 10x10x16 and Output = 5x5x16
#
# - STEP 3: FLATTENING THE NETWORK
#     - Flatten the network with Input = 5x5x16 and Output = 400
#
# - STEP 4: FULLY CONNECTED LAYER
#     - Layer 3: Fully Connected layer with Input = 400 and Output = 120
#     - Apply a RELU Activation function to the output
#
# - STEP 5: ANOTHER FULLY CONNECTED LAYER
#     - Layer 4: Fully Connected Layer with Input = 120 and Output = 84
#     - Apply a RELU Activation function to the output
#
# - STEP 6: FULLY CONNECTED LAYER
#     - Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
from sklearn.model_selection import train_test_split

# %%
image_shape = X_train_gray[i].shape

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(filters = 6, kernel_size = (5,5), activation = 'relu', input_shape = (32,32,1)))
cnn_model.add(AveragePooling2D())

cnn_model.add(Conv2D(filters = 16, kernel_size = (5,5), activation = 'relu', input_shape = (32,32,1)))
cnn_model.add(AveragePooling2D())

cnn_model.add(Flatten())

cnn_model.add(Dense(units = 120, activation = 'relu'))
cnn_model.add(Dense(units=84, activation='relu'))
cnn_model.add(Dense(units=43, activation = 'softmax'))

# %%
cnn_model.compile(loss ='sparse_categorical_crossentropy', optimizer=Adam(lr=0.001),metrics =['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm,y_train,batch_size=500,epochs=50,verbose=1,validation_data = (X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 5s 57ms/step - loss: 3.1129 - accuracy: 0.1936 - val_loss: 2.5553 - val_accuracy: 0.3238
# Epoch 2/50
# 70/70 [==============================] - 3s 46ms/step - loss: 1.5918 - accuracy: 0.5507 - val_loss: 1.4233 - val_accuracy: 0.5864
# Epoch 3/50
# 70/70 [==============================] - 4s 52ms/step - loss: 0.9113 - accuracy: 0.7396 - val_loss: 1.0604 - val_accuracy: 0.6957
# Epoch 4/50
# 70/70 [==============================] - 3s 46ms/step - loss: 0.6683 - accuracy: 0.8111 - val_loss: 0.8851 - val_accuracy: 0.7431
# Epoch 5/50
# 70/70 [==============================] - 3s 46ms/step - loss: 0.5289 - accuracy: 0.8544 - val_loss: 0.7460 - val_accuracy: 0.7857
# Epoch 6/50
# 70/70 [==============================] - 3s 49ms/step - loss: 0.4389 - accuracy: 0.8811 - val_loss: 0.7105 - val_accuracy: 0.7975
# Epoch 7/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.3799 - accuracy: 0.8972 - val_loss: 0.6752 - val_accuracy: 0.8082
# Epoch 8/50
# 70/70 [==============================] - 3s 49ms/step - loss: 0.3309 - accuracy: 0.9114 - val_loss: 0.6746 - val_accuracy: 0.8079
# Epoch 9/50
# 70/70 [==============================] - 3s 47ms/step - loss: 0.2911 - accuracy: 0.9239 - val_loss: 0.6285 - val_accuracy: 0.8159
# Epoch 10/50
# 70/70 [==============================] - 3s 48ms/step - loss: 0.2569 - accuracy: 0.9321 - val_loss: 0.6313 - val_accuracy: 0.8254
# Epoch 11/50
# 70/70 [==============================] - 4s 50ms/step - loss: 0.2324 - accuracy: 0.9399 - val_loss: 0.5857 - val_accuracy: 0.8338
# Epoch 12/50
# 70/70 [==============================] - 3s 49ms/step - loss: 0.2104 - accuracy: 0.9457 - val_loss: 0.5650 - val_accuracy: 0.8379
# Epoch 13/50
# 70/70 [==============================] - 3s 44ms/step - loss: 0.1898 - accuracy: 0.9520 - val_loss: 0.5702 - val_accuracy: 0.8438
# Epoch 14/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.1747 - accuracy: 0.9549 - val_loss: 0.6148 - val_accuracy: 0.8438
# Epoch 15/50
# 70/70 [==============================] - 3s 47ms/step - loss: 0.1640 - accuracy: 0.9576 - val_loss: 0.6080 - val_accuracy: 0.8413
# Epoch 16/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.1476 - accuracy: 0.9632 - val_loss: 0.5664 - val_accuracy: 0.8533
# Epoch 17/50
# 70/70 [==============================] - 3s 48ms/step - loss: 0.1323 - accuracy: 0.9680 - val_loss: 0.6201 - val_accuracy: 0.8415
# Epoch 18/50
# 70/70 [==============================] - 3s 44ms/step - loss: 0.1226 - accuracy: 0.9706 - val_loss: 0.6196 - val_accuracy: 0.8435
# Epoch 19/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.1158 - accuracy: 0.9715 - val_loss: 0.6153 - val_accuracy: 0.8465
# Epoch 20/50
# 70/70 [==============================] - 3s 50ms/step - loss: 0.1098 - accuracy: 0.9716 - val_loss: 0.6337 - val_accuracy: 0.8485
# Epoch 21/50
# 70/70 [==============================] - 3s 46ms/step - loss: 0.1023 - accuracy: 0.9747 - val_loss: 0.6250 - val_accuracy: 0.8515
# Epoch 22/50
# 70/70 [==============================] - 3s 48ms/step - loss: 0.0974 - accuracy: 0.9750 - val_loss: 0.5861 - val_accuracy: 0.8540
# Epoch 23/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.0823 - accuracy: 0.9801 - val_loss: 0.6390 - val_accuracy: 0.8490
# Epoch 24/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.0795 - accuracy: 0.9802 - val_loss: 0.6764 - val_accuracy: 0.8433
# Epoch 25/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.0745 - accuracy: 0.9816 - val_loss: 0.6972 - val_accuracy: 0.8424
# Epoch 26/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.0726 - accuracy: 0.9809 - val_loss: 0.6614 - val_accuracy: 0.8522
# Epoch 27/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.0688 - accuracy: 0.9820 - val_loss: 0.6606 - val_accuracy: 0.8583
# Epoch 28/50
# 70/70 [==============================] - 3s 45ms/step - loss: 0.0587 - accuracy: 0.9861 - val_loss: 0.6887 - val_accuracy: 0.8490
# Epoch 29/50
# 70/70 [==============================] - 3s 46ms/step - loss: 0.0540 - accuracy: 0.9878 - val_loss: 0.6590 - val_accuracy: 0.8571
# Epoch 30/50
# 70/70 [==============================] - 3s 49ms/step - loss: 0.0537 - accuracy: 0.9870 - val_loss: 0.6815 - val_accuracy: 0.8567
# Epoch 31/50
# 70/70 [==============================] - 4s 52ms/step - loss: 0.0518 - accuracy: 0.9863 - val_loss: 0.6457 - val_accuracy: 0.8630
# Epoch 32/50
# 70/70 [==============================] - 4s 53ms/step - loss: 0.0499 - accuracy: 0.9874 - val_loss: 0.7313 - val_accuracy: 0.8519
# Epoch 33/50
# 70/70 [==============================] - 4s 56ms/step - loss: 0.0422 - accuracy: 0.9897 - val_loss: 0.7039 - val_accuracy: 0.8574
# Epoch 34/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0477 - accuracy: 0.9872 - val_loss: 0.7806 - val_accuracy: 0.8478
# Epoch 35/50
# 70/70 [==============================] - 4s 50ms/step - loss: 0.0401 - accuracy: 0.9906 - val_loss: 0.6759 - val_accuracy: 0.8667
# Epoch 36/50
# 70/70 [==============================] - 4s 56ms/step - loss: 0.0373 - accuracy: 0.9903 - val_loss: 0.6679 - val_accuracy: 0.8673
# Epoch 37/50
# 70/70 [==============================] - 4s 52ms/step - loss: 0.0391 - accuracy: 0.9899 - val_loss: 0.6885 - val_accuracy: 0.8694
# Epoch 38/50
# 70/70 [==============================] - 3s 47ms/step - loss: 0.0328 - accuracy: 0.9922 - val_loss: 0.7431 - val_accuracy: 0.8628
# Epoch 39/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0299 - accuracy: 0.9924 - val_loss: 0.7345 - val_accuracy: 0.8556
# Epoch 40/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0410 - accuracy: 0.9889 - val_loss: 0.7615 - val_accuracy: 0.8578
# Epoch 41/50
# 70/70 [==============================] - 4s 53ms/step - loss: 0.0330 - accuracy: 0.9916 - val_loss: 0.7432 - val_accuracy: 0.8608
# Epoch 42/50
# 70/70 [==============================] - 4s 53ms/step - loss: 0.0340 - accuracy: 0.9903 - val_loss: 0.7443 - val_accuracy: 0.8605
# Epoch 43/50
# 70/70 [==============================] - 3s 50ms/step - loss: 0.0307 - accuracy: 0.9918 - val_loss: 0.7404 - val_accuracy: 0.8590
# Epoch 44/50
# 70/70 [==============================] - 3s 48ms/step - loss: 0.0241 - accuracy: 0.9941 - val_loss: 0.7918 - val_accuracy: 0.8651
# Epoch 45/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0247 - accuracy: 0.9935 - val_loss: 0.7918 - val_accuracy: 0.8569
# Epoch 46/50
# 70/70 [==============================] - 3s 50ms/step - loss: 0.0244 - accuracy: 0.9934 - val_loss: 0.7853 - val_accuracy: 0.8635
# Epoch 47/50
# 70/70 [==============================] - 4s 53ms/step - loss: 0.0207 - accuracy: 0.9946 - val_loss: 0.7267 - val_accuracy: 0.8717
# Epoch 48/50
# 70/70 [==============================] - 4s 51ms/step - loss: 0.0271 - accuracy: 0.9921 - val_loss: 0.7546 - val_accuracy: 0.8605
# Epoch 49/50
# 70/70 [==============================] - 3s 48ms/step - loss: 0.0170 - accuracy: 0.9962 - val_loss: 0.7309 - val_accuracy: 0.8748
# Epoch 50/50
# 70/70 [==============================] - 3s 49ms/step - loss: 0.0182 - accuracy: 0.9955 - val_loss: 0.7511 - val_accuracy: 0.8655

# %% [markdown]
# # STEP 5: MODEL EVALUATION

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Accuracy : 0.8466

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

# %%
#get the predictions for the test data
predicted_classes = np.argmax((cnn_model.predict(X_test_gray_norm)), axis = 1)
#get the indices to be plotted
y_true = y_test
# Out:
# 395/395 [==============================] - 1s 3ms/step

# %%
predicted_classes
# Out:
# array([16,  1, 38, ...,  5,  7, 10], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25,25))
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
L = 7
W = 7
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i])
    axes[i].set_title("Prediction={}\n True={}".format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
